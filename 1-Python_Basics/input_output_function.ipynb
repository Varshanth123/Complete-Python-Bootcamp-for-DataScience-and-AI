# %%
'''
input () fuction 
the input fuction stores evry thing as string
for taking integer type data as input we should conert the input in to integer typr 
because as we know it store the data by considering in the form of string 
'''
# simple input taking 
name=input("Enter ur name: ")

# taking integer data as input
age=int(input("Enter your age: "))

print("Your namae is",name)
print("age",age)
# Out:
# Your namae is Varshanth
# age 21

# %%
# output

# simple print statement
print ('Hello World')

# sep()->strings separation in print() fuction
print('varshanth','sunny','prabhakar',sep="->")

# end()->it spacifies what to do in end of an print() fuction
print('varshanth','sunny',sep='->',end=" ")
print('vinay','sadu',sep='->')

# f-strings
age=19
department='computer science and information technology'
print(f"1 am varshanth of {age} years old, perceiving b-tech in {department} department")
# Out:
# Hello World
# varshanth->sunny->prabhakar
# varshanth->sunny vinay->sadu
# 1 am varshanth of 19 years old, perceiving b-tech in computer science and information technology department
