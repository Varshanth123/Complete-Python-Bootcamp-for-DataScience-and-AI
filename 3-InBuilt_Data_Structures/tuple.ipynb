# %% [markdown]
# # Tuple
# -----------
# -> Tuples are immutable<br>
# -> adding values to tuple it will throw an error

# %%
empty_tup=tuple()
print(empty_tup)
tup=("hi","python",2,2,3,4,2,1,4,3)
print(tup)
print(type(tup))
# Out:
# ()
# ('hi', 'python', 2, 2, 3, 4, 2, 1, 4, 3)
# <class 'tuple'>

# %% [markdown]
# # except .append() .insert() and updation all are as same as list
